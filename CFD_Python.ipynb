# %% [markdown]
# # *Curso* **Python - CFD**.

# %%
a = 20
b=2*a
print("b es: ",b)
# Out:
# b es:  40

# %% [markdown]
# Curso introductorio al CFD en python (https://www.youtube.com/watch?v=cDy5XGOokBY&list=PL30F4C5ABCE62CB61&index=32).
# ![Portada.png](attachment:aa7c6054-c4da-480a-8ecf-faad84eab4ca.png)
